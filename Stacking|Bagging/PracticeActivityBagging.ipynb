# %%
import pandas as pd
import numpy as np
from sklearn.pipeline import Pipeline
from sklearn.compose import make_column_selector, ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier, BaggingRegressor, BaggingClassifier
from sklearn.model_selection import cross_val_score, GridSearchCV
from sklearn.neighbors import KNeighborsRegressor, KNeighborsClassifier
from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier

# %%
from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
abalone = fetch_ucirepo(id=1) 
  
# data (as pandas dataframes) 
X = abalone.data.features 
y = abalone.data.targets

# %%
# Bagging Regressor
ct = ColumnTransformer(
    [
        ("dummify", OneHotEncoder(sparse_output = False, handle_unknown='ignore', drop="first"), make_column_selector(dtype_include=object)),
        ("standardize", StandardScaler(), make_column_selector(dtype_include=np.number))
    ]
)

my_pipeline = Pipeline(
    [
        ("preprocessing", ct),
        ("bagging", BaggingRegressor(n_jobs= -1))
    ]
)

parameters = {
    "bagging__estimator": [DecisionTreeRegressor(), KNeighborsRegressor(), RandomForestRegressor()],
    "bagging__n_estimators": [10, 25, 50, 100, 150]
}

gscv = GridSearchCV(my_pipeline, parameters, cv = 5, scoring='r2')
gscv_fitted = gscv.fit(X, y["Rings"])
test_scores = gscv_fitted.cv_results_["mean_test_score"]
# Out:
# /Users/ben/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /Users/ben/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /Users/ben/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /Users/ben/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /Users/ben/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /Users/ben/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /Users/ben/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /Users/ben/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /Users/ben/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /Users/ben/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /Users/ben/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /Users/ben/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /Users/ben/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /Users/ben/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /Users/ben/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /Users/ben/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /Users/ben/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /Users/ben/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /Users/ben/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /Users/ben/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /Users/ben/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(

# %%
gscv_fitted.best_estimator_
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(transformers=[('dummify',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x161c90dd0>),
#                                                  ('standardize',
#                                                   StandardScaler(),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x16181cd10>)])),
#                 ('bagging',
#                  BaggingRegressor(estimator=RandomForestRegressor(),
#                                   n_estimators=50, n_jobs=-1))])

# %%
print(f"Average R^2 for Bagged Decission Tree Regressor: {np.mean(test_scores[0:5])}")
# Out:
# Average R^2 for Bagged Decission Tree Regressor: 0.42626936398517357

# %%
print(f"Average R^2 for Bagged KNeighbors Regressor: {np.mean(test_scores[5:10])}")
# Out:
# Average R^2 for Bagged KNeighbors Regressor: 0.41934320776533324

# %%
print(f"Average R^2 for Bagged Random Forest Regressor: {np.mean(test_scores[10:15])}")
# Out:
# Average R^2 for Bagged Random Forest Regressor: 0.4726450739531696

# %%
# Bagging Classifier
ct = ColumnTransformer(
    [
        ("dummify", OneHotEncoder(sparse_output = False, handle_unknown='ignore', drop="first"), make_column_selector(dtype_include=object)),
        ("standardize", StandardScaler(), make_column_selector(dtype_include=np.number))
    ]
)

my_pipeline = Pipeline(
    [
        ("preprocessing", ct),
        ("bagging", BaggingClassifier(n_jobs= -1, verbose = 1))
    ]
)

parameters = {
    "bagging__estimator": [DecisionTreeClassifier(), KNeighborsClassifier(n_jobs=-1), RandomForestClassifier(n_jobs=-1)],
    "bagging__n_estimators": [10, 25, 50, 100, 150]
}

gscv = GridSearchCV(my_pipeline, parameters, cv = 5, scoring='accuracy')
gscv_fitted = gscv.fit(X, y["Rings"])
test_scores = gscv_fitted.cv_results_["mean_test_score"]
# Out:
# /Users/ben/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done   2 out of  10 | elapsed:    0.7s remaining:    2.9s
# [Parallel(n_jobs=10)]: Done  10 out of  10 | elapsed:    0.8s finished
# [Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done   2 out of  10 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=10)]: Done  10 out of  10 | elapsed:    0.0s finished
# [Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done   2 out of  10 | elapsed:    0.0s remaining:    0.1s
# [Parallel(n_jobs=10)]: Done  10 out of  10 | elapsed:    0.1s finished
# [Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done   2 out of  10 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=10)]: Done  10 out of  10 | elapsed:    0.0s finished
# [Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done   2 out of  10 | elapsed:    0.0s remaining:    0.1s
# [Parallel(n_jobs=10)]: Done  10 out of  10 | elapsed:    0.0s finished
# [Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done   2 out of  10 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=10)]: Done  10 out of  10 | elapsed:    0.0s finished
# [Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done   2 out of  10 | elapsed:    0.0s remaining:    0.1s
# [Parallel(n_jobs=10)]: Done  10 out of  10 | elapsed:    0.0s finished
# [Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done   2 out of  10 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=10)]: Done  10 out of  10 | elapsed:    0.0s finished
# [Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done   2 out of  10 | elapsed:    0.0s remaining:    0.1s
# [Parallel(n_jobs=10)]: Done  10 out of  10 | elapsed:    0.1s finished
# [Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done   2 out of  10 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=10)]: Done  10 out of  10 | elapsed:    0.0s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.6s remaining:    4.3s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    0.7s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.0s remaining:    0.1s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    0.6s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.1s remaining:    0.4s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    0.6s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.0s remaining:    0.2s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    0.1s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.1s remaining:    0.4s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    0.1s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.0s remaining:    0.1s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    0.1s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.1s remaining:    0.4s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    0.1s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.0s remaining:    0.1s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    0.1s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.1s remaining:    0.4s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    0.1s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.0s remaining:    0.1s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    0.1s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.1s remaining:    0.8s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    0.3s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.0s remaining:    0.2s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    0.2s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.1s remaining:    0.7s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    0.2s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.0s remaining:    0.2s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    0.1s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.1s remaining:    0.6s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    0.2s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.0s remaining:    0.2s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    0.1s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.1s remaining:    0.7s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    0.2s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.0s remaining:    0.2s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    0.1s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.1s remaining:    0.7s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    0.3s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.0s remaining:    0.3s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    0.1s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.2s remaining:    1.7s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    0.6s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.1s remaining:    0.4s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    0.3s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.2s remaining:    1.5s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    0.6s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.0s remaining:    0.3s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    0.3s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.2s remaining:    1.6s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    0.6s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.1s remaining:    0.5s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    0.4s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.3s remaining:    1.8s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    0.7s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.1s remaining:    0.4s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    0.4s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.2s remaining:    1.5s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    0.6s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.1s remaining:    0.4s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    0.3s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.4s remaining:    2.8s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    0.8s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.1s remaining:    0.6s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    0.5s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.4s remaining:    3.1s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    1.1s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# /Users/ben/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.6s remaining:    3.9s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    1.3s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.5s remaining:    3.2s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    1.1s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.1s remaining:    0.6s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    0.6s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.4s remaining:    2.7s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    0.9s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.1s remaining:    0.6s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    0.7s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.4s remaining:    2.7s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    1.0s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# /Users/ben/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.5s remaining:    3.7s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    1.2s finished
# [Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done   2 out of  10 | elapsed:    0.6s remaining:    2.3s
# [Parallel(n_jobs=10)]: Done  10 out of  10 | elapsed:    0.6s finished
# [Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done   2 out of  10 | elapsed:    0.0s remaining:    0.1s
# [Parallel(n_jobs=10)]: Done  10 out of  10 | elapsed:    0.1s finished
# [Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done   2 out of  10 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=10)]: Done  10 out of  10 | elapsed:    0.0s finished
# [Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done   2 out of  10 | elapsed:    0.0s remaining:    0.1s
# [Parallel(n_jobs=10)]: Done  10 out of  10 | elapsed:    0.1s finished
# [Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done   2 out of  10 | elapsed:    0.0s remaining:    0.1s
# [Parallel(n_jobs=10)]: Done  10 out of  10 | elapsed:    0.0s finished
# [Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done   2 out of  10 | elapsed:    0.0s remaining:    0.1s
# [Parallel(n_jobs=10)]: Done  10 out of  10 | elapsed:    0.1s finished
# [Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done   2 out of  10 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=10)]: Done  10 out of  10 | elapsed:    0.0s finished
# [Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done   2 out of  10 | elapsed:    0.0s remaining:    0.1s
# [Parallel(n_jobs=10)]: Done  10 out of  10 | elapsed:    0.0s finished
# [Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done   2 out of  10 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=10)]: Done  10 out of  10 | elapsed:    0.0s finished
# [Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done   2 out of  10 | elapsed:    0.0s remaining:    0.1s
# [Parallel(n_jobs=10)]: Done  10 out of  10 | elapsed:    0.1s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.5s remaining:    3.2s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    0.5s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.1s remaining:    0.4s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    0.1s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.0s remaining:    0.1s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    0.5s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.1s remaining:    0.4s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    0.1s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.0s remaining:    0.2s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    0.1s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.0s remaining:    0.3s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    0.1s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.0s remaining:    0.1s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    0.1s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.0s remaining:    0.3s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    0.5s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.0s remaining:    0.2s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    0.1s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.0s remaining:    0.3s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    0.1s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.0s remaining:    0.3s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    0.1s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.1s remaining:    0.6s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    0.2s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.1s remaining:    0.4s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    0.2s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.1s remaining:    0.6s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    0.2s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.0s remaining:    0.3s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    0.1s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.1s remaining:    0.6s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    0.2s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.0s remaining:    0.2s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    0.2s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.1s remaining:    0.6s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    0.2s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.1s remaining:    0.4s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    0.2s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.1s remaining:    0.6s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    0.2s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.1s remaining:    0.7s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    0.4s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.2s remaining:    1.2s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    0.5s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.1s remaining:    0.7s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    0.6s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.2s remaining:    1.2s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    0.4s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.1s remaining:    0.6s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    0.4s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.2s remaining:    1.2s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    0.4s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.1s remaining:    0.9s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    0.4s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.2s remaining:    1.3s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    0.5s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.1s remaining:    0.6s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    0.4s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.2s remaining:    1.1s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    0.4s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.1s remaining:    1.0s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    0.6s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.2s remaining:    1.6s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    0.7s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.1s remaining:    1.0s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    0.6s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.2s remaining:    1.5s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    0.7s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.2s remaining:    1.2s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    0.7s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.2s remaining:    1.6s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    0.8s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.6s remaining:    4.0s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    1.1s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.2s remaining:    1.7s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    0.9s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.2s remaining:    1.1s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    0.7s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    0.2s remaining:    1.7s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    0.8s finished
# [Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done   2 out of  10 | elapsed:    1.9s remaining:    7.5s
# [Parallel(n_jobs=10)]: Done  10 out of  10 | elapsed:    4.1s finished
# [Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# /Users/ben/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [Parallel(n_jobs=10)]: Done   2 out of  10 | elapsed:    1.1s remaining:    4.4s
# [Parallel(n_jobs=10)]: Done  10 out of  10 | elapsed:    2.8s finished
# [Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# /Users/ben/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [Parallel(n_jobs=10)]: Done   2 out of  10 | elapsed:    2.1s remaining:    8.5s
# [Parallel(n_jobs=10)]: Done  10 out of  10 | elapsed:    5.2s finished
# [Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# /Users/ben/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [Parallel(n_jobs=10)]: Done   2 out of  10 | elapsed:    1.2s remaining:    4.9s
# [Parallel(n_jobs=10)]: Done  10 out of  10 | elapsed:    3.0s finished
# [Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done   2 out of  10 | elapsed:    1.9s remaining:    7.4s
# [Parallel(n_jobs=10)]: Done  10 out of  10 | elapsed:    4.1s finished
# [Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# /Users/ben/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [Parallel(n_jobs=10)]: Done   2 out of  10 | elapsed:    1.2s remaining:    4.8s
# [Parallel(n_jobs=10)]: Done  10 out of  10 | elapsed:    3.3s finished
# [Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# /Users/ben/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [Parallel(n_jobs=10)]: Done   2 out of  10 | elapsed:    2.1s remaining:    8.3s
# [Parallel(n_jobs=10)]: Done  10 out of  10 | elapsed:    4.6s finished
# [Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# /Users/ben/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [Parallel(n_jobs=10)]: Done   2 out of  10 | elapsed:    1.0s remaining:    3.9s
# [Parallel(n_jobs=10)]: Done  10 out of  10 | elapsed:    3.1s finished
# [Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done   2 out of  10 | elapsed:    1.9s remaining:    7.7s
# [Parallel(n_jobs=10)]: Done  10 out of  10 | elapsed:    4.1s finished
# [Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done   2 out of  10 | elapsed:    1.1s remaining:    4.6s
# [Parallel(n_jobs=10)]: Done  10 out of  10 | elapsed:    2.9s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    4.6s remaining:   32.3s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:   13.1s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# /Users/ben/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    1.8s remaining:   12.5s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    7.6s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# /Users/ben/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    5.5s remaining:   38.3s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:   16.1s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# /Users/ben/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    2.1s remaining:   15.0s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    8.0s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    4.7s remaining:   32.7s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:   14.2s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# /Users/ben/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    3.0s remaining:   20.8s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:   10.4s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    5.3s remaining:   36.9s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:   15.8s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# /Users/ben/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    2.3s remaining:   16.3s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    8.8s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    4.4s remaining:   30.6s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:   13.3s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# /Users/ben/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    1.8s remaining:   12.5s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:    7.2s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    9.1s remaining:  1.1min
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:   34.6s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# /Users/ben/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    5.3s remaining:   36.9s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:   24.8s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:   10.5s remaining:  1.2min
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:   34.3s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# /Users/ben/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    6.5s remaining:   45.3s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:   29.1s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:   10.3s remaining:  1.2min
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:   39.8s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# /Users/ben/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    8.4s remaining:   58.6s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:   26.8s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# /Users/ben/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    9.0s remaining:  1.1min
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:   29.9s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# /Users/ben/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    7.7s remaining:   54.2s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:   30.3s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    6.6s remaining:   46.4s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:   28.1s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# /Users/ben/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:    5.3s remaining:   37.4s
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:   21.9s finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# /Users/ben/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:   29.9s remaining:  3.5min
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:  2.1min finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# /Users/ben/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:   14.0s remaining:  1.6min
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:  1.9min finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# /Users/ben/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:   32.6s remaining:  3.8min
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:  1.7min finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# /Users/ben/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:   11.8s remaining:  1.4min
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:  1.5min finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# /Users/ben/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:   21.9s remaining:  2.6min
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:  2.6min finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:   14.3s remaining:  1.7min
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:  1.5min finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# /Users/ben/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:   23.8s remaining:  2.8min
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:  1.8min finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# /Users/ben/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:   15.1s remaining:  1.8min
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:  1.5min finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# /Users/ben/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:   25.5s remaining:  3.0min
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:  2.8min finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# /Users/ben/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:   19.9s remaining:  2.3min
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:  1.6min finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# /Users/ben/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:  1.2min remaining:  8.5min
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:  6.4min finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# /Users/ben/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:   27.8s remaining:  3.2min
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:  3.4min finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:  1.7min remaining: 11.8min
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:  9.1min finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# /Users/ben/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:   22.2s remaining:  2.6min
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:  3.0min finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# /Users/ben/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:  1.3min remaining:  9.4min
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:  8.9min finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# /Users/ben/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:   42.4s remaining:  4.9min
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:  4.4min finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# /Users/ben/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:  1.5min remaining: 10.2min
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:  6.3min finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# /Users/ben/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:   41.6s remaining:  4.9min
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:  3.8min finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:   55.1s remaining:  6.4min
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:  4.5min finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:   25.7s remaining:  3.0min
# /Users/ben/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:  3.3min finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done   2 out of  16 | elapsed:   12.0s remaining:  1.4min
# [Parallel(n_jobs=16)]: Done  16 out of  16 | elapsed:   56.4s finished

# %%
gscv_fitted.best_estimator_
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(transformers=[('dummify',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x15f6fdf90>),
#                                                  ('standardize',
#                                                   StandardScaler(),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x15bfc5310>)])),
#                 ('bagging',
#                  BaggingClassifier(estimator=RandomForestClassifier(n_jobs=-1),
#                                    n_estimators=50, n_jobs=-1, verbose=1))])

# %%
print(f"Average Accuracy for Bagged Decission Tree Classifier: {np.mean(test_scores[0:5])}")
# Out:
# Average Accuracy for Bagged Decission Tree Classifier: 0.2369709194052087

# %%
print(f"Average Accuracy for Bagged KNeighbors Classifier: {np.mean(test_scores[5:10])}")
# Out:
# Average Accuracy for Bagged KNeighbors Classifier: 0.2220286508323067

# %%
print(f"Average Accuracy for Bagged Random Forest Classifier: {np.mean(test_scores[10:15])}")
# Out:
# Average Accuracy for Bagged Random Forest Classifier: 0.26024135461135145

# %%
# Random Forest Regressor
ct = ColumnTransformer(
    [
        ("dummify", OneHotEncoder(sparse_output = False, handle_unknown='ignore', drop="first"), make_column_selector(dtype_include=object)),
        ("standardize", StandardScaler(), make_column_selector(dtype_include=np.number))
    ]
)

my_pipeline = Pipeline(
    [
        ("preprocessing", ct),
        ("forest", RandomForestRegressor(n_jobs= -1))
    ]
)

parameters = {
    "forest__n_estimators": [10, 25, 50, 100, 150],
    "forest__min_samples_split": [2, 3, 4, 5, 10],
    "forest__min_samples_leaf": [1, 2, 3, 4, 5, 10]
}

gscv = GridSearchCV(my_pipeline, parameters, cv = 5, scoring='r2')
gscv_fitted = gscv.fit(X, y["Rings"])
test_scores = gscv_fitted.cv_results_["mean_test_score"]

# %%
gscv_fitted.best_estimator_
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(transformers=[('dummify',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x162363c90>),
#                                                  ('standardize',
#                                                   StandardScaler(),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x16217f2d0>)])),
#                 ('forest',
#                  RandomForestRegressor(min_samples_leaf=10,
#                                        min_samples_split=10, n_jobs=-1))])

# %%
print(f"Average R^2 for Random Forest Regressor {np.mean(test_scores)}")
# Out:
# Average R^2 for Random Forest Regressor 0.4547783835227898

# %%
# Random Forest Classifier
ct = ColumnTransformer(
    [
        ("dummify", OneHotEncoder(sparse_output = False, handle_unknown='ignore', drop="first"), make_column_selector(dtype_include=object)),
        ("standardize", StandardScaler(), make_column_selector(dtype_include=np.number))
    ]
)

my_pipeline = Pipeline(
    [
        ("preprocessing", ct),
        ("forest", RandomForestClassifier(n_jobs= -1))
    ]
)

parameters = {
    "forest__n_estimators": [10, 25, 50, 100, 150],
    "forest__min_samples_split": [2, 3, 4, 5, 10],
    "forest__min_samples_leaf": [1, 2, 3, 4, 5, 10]
}

gscv = GridSearchCV(my_pipeline, parameters, cv = 5, scoring='r2')
gscv_fitted = gscv.fit(X, y["Rings"])
test_scores = gscv_fitted.cv_results_["mean_test_score"]
# Out:
# /Users/ben/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(

# %%
gscv_fitted.best_estimator_
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(transformers=[('dummify',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x161d87910>),
#                                                  ('standardize',
#                                                   StandardScaler(),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x15db6af50>)])),
#                 ('forest',
#                  RandomForestClassifier(min_samples_split=10, n_estimators=50,
#                                         n_jobs=-1))])

# %%
print(f"Average R^2 for Random Forest Classifier {np.mean(test_scores)}")
# Out:
# Average R^2 for Random Forest Classifier 0.378032225621694
