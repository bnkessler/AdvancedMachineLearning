# %% [markdown]
# # Final Project - Deep Learning

# %% [raw]
# ---
# author: "Ben Kessler"
# date: "6/8/24"
# output: html
# self-contained: true
# toc: true
# theme: cosmo
# echo: true
# ---

# %% [markdown]
# ## Code Example 1: Image classification via fine-tuning with EfficientNet

# %% [markdown]
# For this code example we will be exploring image classification with EfficientNet. EfficientNet, first introduced in Tan and Le, 2019 is among the most efficient models for image classification and it achieves extremely high accuracy as well. We will be using EfficientNet to classify 5 different species of grapevine leaves. These leaves are harvested once a year and each species of leaf affects the price and taste of the grapes. Being able to accurately classify the leaves could allow for grapes to be picked in a more efficient manner where the leaves can be filtered out later. Leaving the leaves attached would act as an identifier that could be used to separate the different species of grapes as well as saving time when picking the grapes.

# %% [markdown]
# ### Setup and Data

# %%
import numpy as np
import os
import keras
from keras import layers
from keras.applications import EfficientNetB0
import matplotlib.pyplot as plt
from PIL import Image
from sklearn.model_selection import train_test_split
# Out:
# 2024-06-08 15:33:09.056897: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
def load_images_from_folder(folder_path: str, species):
    
    """
    Loads images from a specified file path and labels the images
    Parameters
    ----------
    folder_path: path to folder with images
    species: classification label for images
    Returns
    -------
    images: list of numpy arrays with the images pre normalized
    labels: list of image labels
    """
    
    images = []
    labels = []
    for filename in os.listdir(folder_path):
        img = Image.open(os.path.join(folder_path, filename)).convert("RGB")
        if img is not None:
            img_array = np.array(img)
            img_array = img_array.flatten() / 255.0
            images.append(img_array)
            labels.append(species)
    return images, labels

# %%
ak_path = "/Users/ben/Documents/GitHub/AdvancedMachineLearning/Data/Grapevine_Leaves_Image_Dataset/Ak"
ala_path = "/Users/ben/Documents/GitHub/AdvancedMachineLearning/Data/Grapevine_Leaves_Image_Dataset/Ala_Idris"
buz_path = "/Users/ben/Documents/GitHub/AdvancedMachineLearning/Data/Grapevine_Leaves_Image_Dataset/Buzgulu"
dim_path = "/Users/ben/Documents/GitHub/AdvancedMachineLearning/Data/Grapevine_Leaves_Image_Dataset/Dimnit"
naz_path = "/Users/ben/Documents/GitHub/AdvancedMachineLearning/Data/Grapevine_Leaves_Image_Dataset/Nazli"

# %%
ak_photos, ak_labels = load_images_from_folder(ak_path, 1)
ala_photos, ala_labels = load_images_from_folder(ala_path, 2)
buz_photos, buz_labels = load_images_from_folder(buz_path, 3)
dim_photos, dim_labels = load_images_from_folder(dim_path, 4)
naz_photos, naz_labels = load_images_from_folder(naz_path, 5)

all_photos = np.concatenate([ak_photos, ala_photos, buz_photos, dim_photos, naz_photos])
all_labels = np.concatenate([ak_labels, ala_labels, buz_labels, dim_labels, naz_labels])

# %% [markdown]
# As the images are all of a constant size (511, 511), we do not need to resize them for the model. However, if working with other sized images, a resizing step would be necessary.

# %% [markdown]
# ### Visualizing the Data

# %%
label_dict = {1: "Ak", 2: "Ala_Idris", 3: "Buzgulu", 4: "Dimnit", 5: "Nazli"}
for index, (photo, label) in enumerate(zip(all_photos[0::100], all_labels[0::100])):
    im = photo.reshape(511, 511, 3).astype(float)
    ax = plt.subplot(2, 3, index + 1)
    ax.imshow(im)  
    plt.title("{}".format(label_dict[label]))
    ax.axis("off")

plt.show()

# %% [markdown]
# ### Data Augmentation
# We can use augmentation layers to apply rotations, translations, flips, and contrast changes to the images to better generalize the model.

# %%
NUM_CLASSES = len(set(y_train))

img_augmentation_layers = [
    layers.RandomRotation(factor=0.15),
    layers.RandomTranslation(height_factor=0.1, width_factor=0.1),
    layers.RandomFlip(),
    layers.RandomContrast(factor=0.1),
]


def img_augmentation(images):
    for layer in img_augmentation_layers:
        images = layer(images)
    return images

def input_preprocess_train(image, label):
    image = tf.reshape(image, [511, 511, 3])
    image = img_augmentation(image)
    label = tf.one_hot(label, NUM_CLASSES)
    return image, label


def input_preprocess_test(image, label):
    image = tf.reshape(image, [511, 511, 3])
    label = tf.one_hot(label, NUM_CLASSES)
    return image, label

# %%
BATCH_SIZE = 32

X_train, X_test, y_train, y_test = train_test_split(all_photos, all_labels, test_size=.2)
ds_train = tf.data.Dataset.from_tensor_slices((X_train, y_train))
ds_test = tf.data.Dataset.from_tensor_slices((X_test, y_test))

# %%
ds_train = ds_train.map(input_preprocess_train, num_parallel_calls=tf.data.AUTOTUNE)
ds_train = ds_train.batch(batch_size=BATCH_SIZE, drop_remainder=True)
ds_train = ds_train.prefetch(tf.data.AUTOTUNE)

ds_test = ds_test.map(input_preprocess_test, num_parallel_calls=tf.data.AUTOTUNE)
ds_test = ds_test.batch(batch_size=BATCH_SIZE, drop_remainder=True)

# %% [markdown]
# ### Training a model from scratch

# %%
IMG_SIZE = 511

model = EfficientNetB0(
    include_top=True,
    weights=None,
    classes=NUM_CLASSES,
    input_shape=(IMG_SIZE, IMG_SIZE, 3),
)
model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

model.summary()

epochs = 40  # @param {type: "slider", min:10, max:100}
hist = model.fit(ds_train, epochs=epochs, validation_data=ds_test)
# Out:
# Model: "efficientnetb0"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 511, 511,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling           │ (None, 511, 511,  │          0 │ input_layer[0][0] │
# │ (Rescaling)         │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normalization       │ (None, 511, 511,  │          7 │ rescaling[0][0]   │
# │ (Normalization)     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# ...

# %%
def plot_hist(hist):
    plt.plot(hist.history["accuracy"])
    plt.plot(hist.history["val_accuracy"])
    plt.title("model accuracy")
    plt.ylabel("accuracy")
    plt.xlabel("epoch")
    plt.legend(["train", "validation"], loc="upper left")
    plt.show()


plot_hist(hist)

# %% [markdown]
# ### Transfer Learning from pre-trained weights

# %%
IMG_SIZE = 511

def build_model(num_classes):
    inputs = layers.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
    model = EfficientNetB0(include_top=False, input_tensor=inputs, weights="imagenet")

    # Freeze the pretrained weights
    model.trainable = False

    # Rebuild top
    x = layers.GlobalAveragePooling2D(name="avg_pool")(model.output)
    x = layers.BatchNormalization()(x)

    top_dropout_rate = 0.2
    x = layers.Dropout(top_dropout_rate, name="top_dropout")(x)
    outputs = layers.Dense(num_classes, activation="softmax", name="pred")(x)

    # Compile
    model = keras.Model(inputs, outputs, name="EfficientNet")
    optimizer = keras.optimizers.Adam(learning_rate=1e-2)
    model.compile(
        optimizer=optimizer, loss="categorical_crossentropy", metrics=["accuracy"]
    )
    return model

# %%
model = build_model(num_classes=NUM_CLASSES)

epochs = 25  # @param {type: "slider", min:8, max:80}
hist = model.fit(ds_train, epochs=epochs, validation_data=ds_test)
plot_hist(hist)

# %%
def unfreeze_model(model):
    # We unfreeze the top 20 layers while leaving BatchNorm layers frozen
    for layer in model.layers[-20:]:
        if not isinstance(layer, layers.BatchNormalization):
            layer.trainable = True

    optimizer = keras.optimizers.Adam(learning_rate=1e-5)
    model.compile(
        optimizer=optimizer, loss="categorical_crossentropy", metrics=["accuracy"]
    )


unfreeze_model(model)

epochs = 4  # @param {type: "slider", min:4, max:10}
hist = model.fit(ds_train, epochs=epochs, validation_data=ds_test)
plot_hist(hist)
